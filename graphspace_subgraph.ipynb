# %%
# Using https://graphspace-python-library.readthedocs.io/en/develop/tutorial/tutorial.html

# %%
from graphspace_python.graphs.classes.gsgraph import GSGraph
import plotly.express as px
import json
import pandas as pd

# %%
from graphspace_python.api.client import GraphSpace
graphspace = GraphSpace('aboelela.ayah@gmail.com', 'awesomemuhaddithat')

# %%
df = pd.read_csv('narratorsTESTING.csv')

# %%
df
# Out:
#     scholar_indx                                               name  \
# 0              1  Prophet Muhammad(saw) ( محمّد صلّی اللہ علیہ و...
# 1              2  Abu Bakr As-Siddique ( أبو بكر الصديق ( رضي ال...
# 2              3  'Umar ibn al-Khattab ( عمر بن الخطاب بن نفيل (...
# 3              4  'Uthman ibn 'Affaan ( عثمان بن عفان ( رضي الله...
# 4              5  Ali ibn Abi Talib ( علي بن أبي طالب بن عبد الم...
# 5              6  Talha ibn 'Ubaidullah ( طلحة بن عبيد الله ( رض...
# 6              7  Zubayr ibn al-Awwam ( الزبير بن العوام بن خويل...
# 7              8  'Abdur Rahman Ibn 'Awf ( عبد الرحمن بن عوف ( ر...
# 8              9  Sa'd ibn Abi Waqqas ( سعد بن أبي وقاص ( رضي ال...
# 9             10  Abu 'Ubaidah ibn al-Jarrah ( أبو عبيدة بن الجر...
# 10            11        Sa'id bin Zayd ( سعيد بن زيد ( رضي الله عنه
# 11            13  Abu Hurairah ( أبو هريرة - عبد الرحمن بن صخر ا...
# 12            52   Sawda bint Zam'a ( سودة بنت زمعة ( رضي الله عنها
# ...

# %%
# from muhaddithat-networks cleaning.ipynb
#build corrected columns for students_inds and teachers_inds
#strings of lists of numbers ---> lists of numeric indices
students_inds_corrected = []
teachers_inds_corrected = []
for indx, data in df.loc[:,['students_inds','teachers_inds']].iterrows():
    
    students = data[0]
    if pd.isna(students):
        students_inds_corrected.append(students)
    elif isinstance(students, str):
        students_temp = []
        for item in students.split(','):
            if item.strip().isdigit():
                students_temp.append(int(item.strip()))
            else:
                print("non-numeric in students_inds at id="+str(indx)+", value: "+item.strip())
        students_inds_corrected.append(students_temp)
    else:
        raise TypeError("students_inds value at indx "+str(indx)+" is neither str nor NaN")
    
    teachers = data[1]
    if pd.isna(teachers):
        teachers_inds_corrected.append(teachers)
    elif isinstance(teachers, str):
        teachers_temp = []
        for item in teachers.split(','):
            if item.strip().isdigit():
                teachers_temp.append(int(item.strip()))
            else:
                print("non-numeric in teachers_inds at id="+str(indx)+", value: "+item.strip())
        teachers_inds_corrected.append(teachers_temp)
    else:
        raise TypeError("teachers_inds value at indx "+str(indx)+" is neither str nor NaN")

#remove old columns and assign corrected columns to the dataset
del df['students_inds']
del df['teachers_inds']
df = df.assign(students_inds=students_inds_corrected, teachers_inds=teachers_inds_corrected)
del students_inds_corrected #remove unneeded variables
del teachers_inds_corrected

# %%
G = GSGraph()
# set metadata for the graph
metadata = {
     'description': 'This is a graph of hadith narrators - work in progress',
     'directed': True
}
G.set_data(metadata)
###
#add nodes with attributes
#for indx, data in df.loc[:,['name']].iterrows():
#NOTE: AS OF 7/24/22, ^ THAT'S what I was using to iterate through the data. I changed it to the following so "gender" wouldn't get a key attribute error. 

    # TO-DO: make a new column just for the shortened/english name for the label
for indx, data in df.iterrows():
    # adding the SCHOLAR INDEX as the node ID, not the data row number as before
    G.add_node(int(df['scholar_indx'][indx]),name=data['name'], label=data['name'],gender=data['gender'])

# keep track of all the scholar indices who have nodes in the graph/entries in the data
# this is because I only want to include nodes of scholars who have their own entries in the data set, and not necessarily any scholar that may be listed as a student/teacher of another.
scholars_with_entries = []
for indx, scholar_indx in df.loc[:,['scholar_indx']].iterrows():
    scholars_with_entries += [int(scholar_indx)]

    
#add edges from students_inds
for teacher, students in df['students_inds'].items():
   # print((df['scholar_indx'][teacher]) == a[teacher])
    #print(df['scholar_indx'][teacher]) # this is the teacher ID 
    if isinstance(pd.isna(students), bool):
        pass
    else:
        for student in students:
            # check to make sure the student/teacher each have their own entries in the data
            # note: once I make it so that the teacher/student lists are only for nodes that exist in the data, I might not need this except for as a sanity check
            if not ((student in scholars_with_entries) & (int(df['scholar_indx'][teacher]) in scholars_with_entries)):
                pass
            elif G.has_edge(int(df['scholar_indx'][teacher]), student):
                pass
            else:
                #print(int(df['scholar_indx'][teacher]))
                #print(student)
                G.add_edge(int(df['scholar_indx'][teacher]), student, directed=True)

#add edges from teachers_inds (AYAH: maybe here I can somehow attach the hadiths to the edge data?)
for student, teachers in df['teachers_inds'].items():
    #df['scholar_indx'][student] # this is the student ID
    if isinstance(pd.isna(teachers), bool):
        pass
    else:
        for teacher in teachers:
            # check to make sure the student/teacher each have their own entries in the data
            if not ((int(df['scholar_indx'][student]) in scholars_with_entries) & (teacher in scholars_with_entries)):
                pass
            elif G.has_edge(teacher, int(df['scholar_indx'][student])):
                pass
            else:
                G.add_edge(teacher, int(df['scholar_indx'][student]), directed=True)

# %%
graph = graphspace.post_graph(G)
graph.get_name()
graph.id
# Out:
# 33974
